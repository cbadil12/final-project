# %% [markdown]
# # Descarga de datos con APIs

# %%
# === 1. IMPORTS Y CONFIGURACIÓN ===

from newsapi import NewsApiClient
import requests
import feedparser
import pandas as pd
from datetime import datetime, timedelta
import time

# Claves API
# NEWSAPI_KEY = 'd7c0734c87d04ed69ea623c77e7406b3'
NEWSAPI_KEY = '467b44feac1e4990a18822c9ff99074c'
GNEWS_API_KEY = '8b50c1681d21553b25406f228aca6938'
CRYPTOPANIC_API_KEY = 'b4124ef89cfd6fdce685b3218b21a6378dc6ed01'

# Inicializar NewsAPI
newsapi = NewsApiClient(api_key=NEWSAPI_KEY)

RSS_FEEDS = {
    'BTC': [
        "https://feeds.feedburner.com/CoinDesk",
        "https://cointelegraph.com/rss",
        "https://www.newsbtc.com/feed/",
        "https://bitcoinmagazine.com/.rss/full/",
        "https://cryptopotato.com/feed/",
        "https://decrypt.co/feed",
        "https://www.theblock.co/feed/rss",
        "https://cryptobriefing.com/feed/",
        "https://blockworks.co/rss.xml",
        "https://www.dlnews.com/rss/",
        "https://u.today/rss",
        "https://beincrypto.com/feed/",
        "https://www.bitcoin.com/feed/",
        "https://cryptoslate.com/feed/",
        "https://ambcrypto.com/feed/"
    ],
    'TECH': [
        "https://techcrunch.com/feed/",
        "https://www.theverge.com/rss/index.xml",
        "https://arstechnica.com/feed/",
        "https://www.wired.com/feed/rss",
        "https://gizmodo.com/rss",
        "https://www.engadget.com/rss.xml",
        "https://venturebeat.com/feed/",
        "https://www.zdnet.com/topic/artificial-intelligence/rss/",
        "https://www.technologyreview.com/feed/"
    ],
    'MACRO': [
        "https://feeds.bbci.co.uk/news/business/rss.xml",
        "https://www.cnbc.com/id/100003114/device/rss/rss.html",
        "https://www.ft.com/global-economy?format=rss",
        "https://www.bloomberg.com/feeds/markets.rss",
        "https://www.wsj.com/xml/rss/3_7085.xml",
        "https://www.economist.com/finance-and-economics/rss.xml",
        "https://www.reuters.com/rssFeed/businessNews",
        "https://www.marketwatch.com/rss/economy-politics",
        "https://www.investopedia.com/rss/articles.xml",
        "https://seekingalpha.com/api/v2/news.rss?tag=market-news"
    ]
}

print("✅ Configuración lista. APIs y feeds definidos.")
# Out:
# ✅ Configuración lista. APIs y feeds definidos.

# %%
# === 2. DEFINICIÓN DE PALABRAS CLAVE POR EJE ===

KEYWORDS_BTC = (
    "(bitcoin OR btc OR cryptocurrency OR 'crypto price' OR 'digital gold' OR halving) "
    "NOT (fraud OR scam OR hack OR theft)"
)

KEYWORDS_TECH = (
    "(blockchain OR web3 OR 'RAM memory' OR 'semiconductor shortage' OR 'AI investment' OR 'DeFi' OR 'mining rig')"
)

KEYWORDS_MACRO = (
    "(FED OR 'interest rate' OR inflation OR recession OR 'treasury bond' OR 'stock market crash' OR 'quantitative easing')"
)

keyword_map = {
    'BTC': KEYWORDS_BTC,
    'TECH': KEYWORDS_TECH,
    'MACRO': KEYWORDS_MACRO
}

# Rango de fechas (cámbialo fácil)
FECHA_INICIO = '2025-11-17'
FECHA_FIN = '2025-12-17'

print("✅ Palabras clave definidas para los 3 ejes.")
# Out:
# ✅ Palabras clave definidas para los 3 ejes.

# %%
# === 3. FUNCIONES PARA CADA FUENTE (CON DEBUG) ===

def fetch_newsapi(query, from_date, to_date, axis):
    articles = []
    try:
        response = newsapi.get_everything(
            q=query,
            language='en',
            from_param=from_date,
            to=to_date,
            sort_by='relevancy',
            page_size=100
        )
        if response['status'] == 'ok':
            for article in response['articles']:
                articles.append({
                    'publishedAt': article['publishedAt'],
                    'title': article['title'],
                    'description': article['description'],
                    'source': article['source']['name'],
                    'axis': axis
                })
    except Exception as e:
        print(f"❌ NewsAPI error ({axis}): {e}")
    return articles

def fetch_gnews(query, from_date, to_date, axis):
    articles = []
    params = {
        "q": query,
        "from": from_date,
        "to": to_date,
        "lang": "en",
        "max": 100,
        "token": GNEWS_API_KEY
    }
    try:
        response = requests.get("https://gnews.io/api/v4/search", params=params, timeout=15)
        data = response.json()
        print(f"Debug GNews ({axis}): Status {response.status_code}")
        if 'information' in data:
            print(f"  Aviso GNews: {data['information']}")
        raw_articles = data.get('articles', [])
        for article in raw_articles:
            articles.append({
                'publishedAt': article['publishedAt'],
                'title': article['title'],
                'description': article.get('description'),
                'source': article['source']['name'],
                'axis': axis
            })
        print(f"  - {axis} GNews: {len(articles)} artículos (con delay 12h en free)")
    except Exception as e:
        print(f"❌ GNews error ({axis}): {e}")
    return articles

def fetch_cryptopanic():
    articles = []
    params = {
        "auth_token": CRYPTOPANIC_API_KEY,
        "public": "true",
        "kind": "news"
    }
    try:
        response = requests.get("https://cryptopanic.com/api/v1/posts/", params=params, timeout=15)
        print(f"Debug CryptoPanic: Status {response.status_code}")
        print(f"  Respuesta cruda (primeros 200 chars): {response.text[:200]}")
        data = response.json()
        for post in data.get("results", []):
            articles.append({
                'publishedAt': post['published_at'],
                'title': post['title'],
                'description': None,
                'source': post.get('source', {}).get('title', 'CryptoPanic'),
                'axis': 'BTC'
            })
    except Exception as e:
        print(f"❌ CryptoPanic error detallado: {e}")
    return articles

def fetch_rss(axis):
    articles = []
    for feed_url in RSS_FEEDS.get(axis, []):
        feed = feedparser.parse(feed_url)
        print(f"Debug RSS ({axis}, {feed_url}): {len(feed.entries)} entradas")
        for entry in feed.entries:
            articles.append({
                'publishedAt': entry.get('published'),
                'title': entry.title,
                'description': entry.get('summary'),
                'source': feed.feed.get('title', 'RSS'),
                'axis': axis
            })
    return articles

print("✅ Funciones de fetch listas (con debug).")
# Out:
# ✅ Funciones de fetch listas (con debug).

# %%
# === 4. BUCLE PRINCIPAL DE EXTRACCIÓN ===

start_date = datetime.strptime(FECHA_INICIO, '%Y-%m-%d')
end_date = datetime.strptime(FECHA_FIN, '%Y-%m-%d') + timedelta(days=1)

all_news_data = {'BTC': [], 'TECH': [], 'MACRO': []}

# CryptoPanic y RSS una vez
print("Buscando CryptoPanic...")
all_news_data['BTC'].extend(fetch_cryptopanic())

print("Buscando RSS feeds...")
for axis in ['BTC', 'TECH', 'MACRO']:
    rss_articles = fetch_rss(axis)
    all_news_data[axis].extend(rss_articles)

current_date = start_date
print(f"--- INICIANDO EXTRACCIÓN DÍA A DÍA ---\nRANGO: {FECHA_INICIO} a {FECHA_FIN}")

while current_date < end_date:
    day_str = current_date.strftime('%Y-%m-%d')
    print(f"\nProcesando día: {day_str}")
    
    for axis_name, keyword_query in keyword_map.items():
        newsapi_articles = fetch_newsapi(keyword_query, day_str, day_str, axis_name)
        all_news_data[axis_name].extend(newsapi_articles)
        print(f"  - {axis_name} NewsAPI: {len(newsapi_articles)} artículos")
        
        gnews_articles = fetch_gnews(keyword_query, day_str, day_str, axis_name)
        all_news_data[axis_name].extend(gnews_articles)
        
        time.sleep(0.6)  # Pausa segura
    
    current_date += timedelta(days=1)

print("\n--- EXTRACCIÓN FINALIZADA ---")
for axis, data in all_news_data.items():
    print(f"Total {axis}: {len(data)} artículos")
# Out:
# Buscando CryptoPanic...
# Debug CryptoPanic: Status 404
#   Respuesta cruda (primeros 200 chars): <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="viewport" cont
# ❌ CryptoPanic error detallado: Expecting value: line 1 column 1 (char 0)
# Buscando RSS feeds...
# Debug RSS (BTC, https://feeds.feedburner.com/CoinDesk): 25 entradas
# Debug RSS (BTC, https://cointelegraph.com/rss): 30 entradas
# Debug RSS (BTC, https://www.newsbtc.com/feed/): 10 entradas
# Debug RSS (BTC, https://bitcoinmagazine.com/.rss/full/): 10 entradas
# Debug RSS (BTC, https://cryptopotato.com/feed/): 36 entradas
# Debug RSS (BTC, https://decrypt.co/feed): 54 entradas
# Debug RSS (BTC, https://www.theblock.co/feed/rss): 0 entradas
# Debug RSS (BTC, https://cryptobriefing.com/feed/): 30 entradas
# Debug RSS (BTC, https://blockworks.co/rss.xml): 0 entradas
# Debug RSS (BTC, https://www.dlnews.com/rss/): 0 entradas
# Debug RSS (BTC, https://u.today/rss): 92 entradas
# Debug RSS (BTC, https://beincrypto.com/feed/): 12 entradas
# Debug RSS (BTC, https://www.bitcoin.com/feed/): 0 entradas
# Debug RSS (BTC, https://cryptoslate.com/feed/): 10 entradas
# Debug RSS (BTC, https://ambcrypto.com/feed/): 16 entradas
# Debug RSS (TECH, https://techcrunch.com/feed/): 20 entradas
# Debug RSS (TECH, https://www.theverge.com/rss/index.xml): 10 entradas
# Debug RSS (TECH, https://arstechnica.com/feed/): 20 entradas
# Debug RSS (TECH, https://www.wired.com/feed/rss): 50 entradas
# Debug RSS (TECH, https://gizmodo.com/rss): 20 entradas
# Debug RSS (TECH, https://www.engadget.com/rss.xml): 50 entradas
# Debug RSS (TECH, https://venturebeat.com/feed/): 7 entradas
# Debug RSS (TECH, https://www.zdnet.com/topic/artificial-intelligence/rss/): 0 entradas
# Debug RSS (TECH, https://www.technologyreview.com/feed/): 10 entradas
# Debug RSS (MACRO, https://feeds.bbci.co.uk/news/business/rss.xml): 53 entradas
# Debug RSS (MACRO, https://www.cnbc.com/id/100003114/device/rss/rss.html): 30 entradas
# Debug RSS (MACRO, https://www.ft.com/global-economy?format=rss): 25 entradas
# Debug RSS (MACRO, https://www.bloomberg.com/feeds/markets.rss): 0 entradas
# Debug RSS (MACRO, https://www.wsj.com/xml/rss/3_7085.xml): 0 entradas
# Debug RSS (MACRO, https://www.economist.com/finance-and-economics/rss.xml): 300 entradas
# Debug RSS (MACRO, https://www.reuters.com/rssFeed/businessNews): 0 entradas
# Debug RSS (MACRO, https://www.marketwatch.com/rss/economy-politics): 0 entradas
# Debug RSS (MACRO, https://www.investopedia.com/rss/articles.xml): 0 entradas
# Debug RSS (MACRO, https://seekingalpha.com/api/v2/news.rss?tag=market-news): 0 entradas
# --- INICIANDO EXTRACCIÓN DÍA A DÍA ---
# RANGO: 2025-11-17 a 2025-12-17
#
# Procesando día: 2025-11-17
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 44 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 53 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-18
#   - BTC NewsAPI: 99 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 32 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 61 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-19
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 41 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 49 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-20
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 47 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 83 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-21
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 34 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 55 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-22
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 14 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 17 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-23
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 15 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 12 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-24
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 48 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 65 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-25
#   - BTC NewsAPI: 99 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 49 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 59 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-26
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 33 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 76 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-27
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 40 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 70 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-28
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 38 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 57 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-29
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 24 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 27 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-11-30
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 26 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 18 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-01
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 53 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 82 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-02
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 27 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 68 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-03
#   - BTC NewsAPI: 98 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 42 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 63 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-04
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 51 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 49 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-05
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 32 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 74 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-06
#   - BTC NewsAPI: 99 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 16 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 23 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-07
#   - BTC NewsAPI: 98 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 19 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 23 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-08
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 36 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 69 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-09
#   - BTC NewsAPI: 96 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 33 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 85 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-10
#   - BTC NewsAPI: 94 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 36 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 99 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-11
#   - BTC NewsAPI: 98 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 31 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 80 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-12
#   - BTC NewsAPI: 97 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 53 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 66 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-13
#   - BTC NewsAPI: 99 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 24 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 24 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-14
#   - BTC NewsAPI: 100 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 15 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 27 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-15
#   - BTC NewsAPI: 96 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 32 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 71 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-16
#   - BTC NewsAPI: 97 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 33 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 66 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# Procesando día: 2025-12-17
#   - BTC NewsAPI: 0 artículos
# Debug GNews (BTC): Status 400
#   - BTC GNews: 0 artículos (con delay 12h en free)
#   - TECH NewsAPI: 0 artículos
# Debug GNews (TECH): Status 400
#   - TECH GNews: 0 artículos (con delay 12h en free)
#   - MACRO NewsAPI: 0 artículos
# Debug GNews (MACRO): Status 400
#   - MACRO GNews: 0 artículos (con delay 12h en free)
#
# --- EXTRACCIÓN FINALIZADA ---
# Total BTC: 3295 artículos
# Total TECH: 1205 artículos
# Total MACRO: 2079 artículos

# %%
# === 5. CONSOLIDAR Y GUARDAR CSV ===

full_articles = all_news_data['BTC'] + all_news_data['TECH'] + all_news_data['MACRO']
df_raw_news = pd.DataFrame(full_articles)

fecha_actual = datetime.now().strftime('%Y.%m.%d')
filename = f'{fecha_actual}.noticias_raw_sentimiento.csv'

df_raw_news.to_csv(filename, index=False)

print(f"\n✅ Datos guardados en '{filename}'")
print("Total artículos:", len(df_raw_news))
print("\nEjemplo:")
display(df_raw_news.head(10))
# Out:
# ✅ Datos guardados en '2025.12.17.noticias_raw_sentimiento.csv'
# Total artículos: 6579
#
# Ejemplo:
#                        publishedAt  \
# 0  Wed, 17 Dec 2025 17:28:00 +0000
# 1  Wed, 17 Dec 2025 17:20:57 +0000
# 2  Wed, 17 Dec 2025 17:14:34 +0000
# 3  Wed, 17 Dec 2025 17:13:53 +0000
# 4  Wed, 17 Dec 2025 17:06:18 +0000
# 5  Wed, 17 Dec 2025 16:51:08 +0000
# 6  Wed, 17 Dec 2025 16:43:02 +0000
# 7  Wed, 17 Dec 2025 16:20:45 +0000
# 8  Wed, 17 Dec 2025 16:11:57 +0000
# 9  Wed, 17 Dec 2025 16:10:50 +0000
#
#                                                title description  \
# 0  Polkadot's DOT drops 3% to $1.83 as crypto mar...
# 1  BNB drops nearly 3% to as bitcoin whipsaw and ...
# 2  Dogecoin and shiba inu test lower levels after...
# 3  Crypto Long & Short: What the DOJ’s Massive Cr...
# 4  XRP falls 5% as bitcoin’s sudden pump and dump...
# 5  Crypto stocks pare gains as bitcoin retreats f...
# 6  Crypto industry insiders meet with key senator...
# 7  The Protocol: Bug that can drain all your toke...
# 8  Bitcoin tumbles back below $88,000 as gains ev...
# 9  Robinhood looks better placed than Coinbase fo...
#
#                                               source axis
# 0  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 1  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 2  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 3  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 4  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 5  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 6  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 7  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 8  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC
# 9  CoinDesk: Bitcoin, Ethereum, Crypto News and P...  BTC

# %%
display(df_raw_news.tail(10))
# Out:
#                publishedAt                                              title  \
# 6569  2025-12-16T18:55:22Z  EU moves to ease 2035 ban on internal combusti...
# 6570  2025-12-16T02:39:00Z  Oil Prices Slip as Ukraine Peace Talks Progres...
# 6571  2025-12-16T10:02:05Z  India's exports defy tariffs, strengthen hand ...
# 6572  2025-12-16T11:59:39Z  Prices of agri commodities poised to rise in 2026
# 6573  2025-12-16T18:59:54Z  There aren't many balls left for JioStar to ma...
# 6574  2025-12-16T19:58:22Z  EU plans to ease 2035 ban on internal combusti...
# 6575  2025-12-16T14:37:49Z  Why your next smartphone will cost way more in...
# 6576  2025-12-16T07:14:12Z  The farmers and Mitsotakis, the Swiss-franc la...
# 6577  2025-12-16T04:51:26Z  Shares in Chinese Nvidia challenger surge on d...
# 6578  2025-12-16T02:15:38Z   Economic Digest: Nepal’s Business News in a Snap
#
#                                             description              source  \
# 6569  FRANKFURT, Germany (AP) — European officials o...      Financial Post
# 6570  Oil prices were under pressure in early Asian ...        OilPrice.com
# 6571  Indian exports saw a significant jump in Novem...  The Times of India
# 6572  Global agricultural commodity prices are expec...        BusinessLine
# 6573  Despite strong viewership and competitive on-f...  The Times of India
# 6574  The EU's commission is responding to appeals f...                 PBS
# 6575  Your next smartphone is going to cost signific...         Rolling Out
# 6576  National Bank and insurance companies & will S...       Protothema.gr
# 6577  Shanghai (AFP) Dec 5, 2025 -\n\n Faith in the ...         Space Daily
# 6578  KATHMANDU: Economic Digest offers a concise ye...       Khabarhub.com
#
#        axis
# 6569  MACRO
# 6570  MACRO
# 6571  MACRO
# 6572  MACRO
# 6573  MACRO
# 6574  MACRO
# 6575  MACRO
# 6576  MACRO
# 6577  MACRO
# 6578  MACRO
